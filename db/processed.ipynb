# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('IndianFoodDatasetCSV.csv' ,encoding = 'unicode_escape')
df.shape
# Out:
# (6871, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ï»¿Srno                 6871 non-null   int64
#  1   RecipeName              6871 non-null   object
#  2   TranslatedRecipeName    6871 non-null   object
#  3   Ingredients             6865 non-null   object
#  4   TranslatedIngredients   6865 non-null   object
#  5   PrepTimeInMins          6871 non-null   int64
#  6   CookTimeInMins          6871 non-null   int64
#  7   TotalTimeInMins         6871 non-null   int64
#  8   Servings                6871 non-null   int64
#  9   Cuisine                 6871 non-null   object
#  10  Course                  6871 non-null   object
#  11  Diet                    6871 non-null   object
#  12  Instructions            6871 non-null   object
#  13  TranslatedInstructions  6871 non-null   object
# ...

# %%
df = df.drop(['RecipeName','Ingredients', 'Instructions'],axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6871 entries, 0 to 6870
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ï»¿Srno                 6871 non-null   int64
#  1   TranslatedRecipeName    6871 non-null   object
#  2   TranslatedIngredients   6865 non-null   object
#  3   PrepTimeInMins          6871 non-null   int64
#  4   CookTimeInMins          6871 non-null   int64
#  5   TotalTimeInMins         6871 non-null   int64
#  6   Servings                6871 non-null   int64
#  7   Cuisine                 6871 non-null   object
#  8   Course                  6871 non-null   object
#  9   Diet                    6871 non-null   object
#  10  TranslatedInstructions  6871 non-null   object
#  11  URL                     6871 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 644.3+ KB

# %%
df.head()
# Out:
#    ï»¿Srno                               TranslatedRecipeName  \
# 0        1                               Masala Karela Recipe
# 1        2                         Spicy Tomato Rice (Recipe)
# 2        3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3        4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4        5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                TranslatedIngredients  PrepTimeInMins  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1  2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...              20
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...              15
# 4  1 tablespoon chana dal, 1 tablespoon white ura...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# ...

# %%
df.rename(columns = {'TranslatedRecipeName' : 'RecipeName', 'TranslatedIngredients': 'Ingredients'},inplace = True)

# %%
df.head()
# Out:
#    ï»¿Srno                                         RecipeName  \
# 0        1                               Masala Karela Recipe
# 1        2                         Spicy Tomato Rice (Recipe)
# 2        3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3        4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4        5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  PrepTimeInMins  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1  2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...              20
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...              15
# 4  1 tablespoon chana dal, 1 tablespoon white ura...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# ...

# %%
df.rename(columns = {'TranslatedInstructions' : 'Instructions'},inplace = True)

# %%
df.head()
# Out:
#    ï»¿Srno                                         RecipeName  \
# 0        1                               Masala Karela Recipe
# 1        2                         Spicy Tomato Rice (Recipe)
# 2        3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3        4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4        5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  PrepTimeInMins  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1  2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...              20
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...              15
# 4  1 tablespoon chana dal, 1 tablespoon white ura...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# ...

# %%
pd.io.sql.get_schema(df.reset_index(), 'recipetable')
# Out:
# 'CREATE TABLE "recipetable" (\n"index" INTEGER,\n  "ï»¿Srno" INTEGER,\n  "RecipeName" TEXT,\n  "Ingredients" TEXT,\n  "PrepTimeInMins" INTEGER,\n  "CookTimeInMins" INTEGER,\n  "TotalTimeInMins" INTEGER,\n  "Servings" INTEGER,\n  "Cuisine" TEXT,\n  "Course" TEXT,\n  "Diet" TEXT,\n  "Instructions" TEXT,\n  "URL" TEXT\n)'

# %%
print(pd.io.sql.get_schema(df.reset_index(), 'recipetable'))
# Out:
# CREATE TABLE "recipetable" (
# "index" INTEGER,
#   "ï»¿Srno" INTEGER,
#   "RecipeName" TEXT,
#   "Ingredients" TEXT,
#   "PrepTimeInMins" INTEGER,
#   "CookTimeInMins" INTEGER,
#   "TotalTimeInMins" INTEGER,
#   "Servings" INTEGER,
#   "Cuisine" TEXT,
#   "Course" TEXT,
#   "Diet" TEXT,
#   "Instructions" TEXT,
#   "URL" TEXT
# )

# %%
df.rename(columns = {'RecipeID' : 'RecipeId'},inplace = True)

# %%
df.shape
# Out:
# (6871, 12)

# %%
df.to_csv('processed_data.csv', index = False, encoding='utf-8')

# %%
df = pd.read_csv('processed_data.csv',encoding = 'utf-8')

# %%
df['Instructions'].replace(regex=True, inplace=True, to_replace=r'[^0-9a-zA-Z.\- ]', value=r'')

# %%
df['Diet'].replace(regex=True, inplace=True, to_replace=r'[^0-9a-zA-Z.\- ]', value=r'')

# %%
df.head()
# Out:
#    RecipeId                                         RecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2                           Spicy Tomato Rice Recipe
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  PrepTimeInMins  \
# 0  6 Karela Bitter Gourd Pavakkai - deseededSalt ...              15
# 1  2-1  2 cups rice - cooked 3 tomatoes 3 teaspoo...               5
# 2  1-12 cups Rice Vermicelli Noodles Thin1 Onion ...              20
# 3  500 grams Chicken2 Onion - chopped1 Tomato - c...              15
# 4  1 tablespoon chana dal 1 tablespoon white urad...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# ...

# %%
chef = pd.read_csv('Chefs.csv')

# %%
cheflist = []

# %%
cheflist = chef["username"].to_numpy()

# %%
print(cheflist)
# Out:
# ['super_carabeef_911' 'clean_fox_988' 'uninterested_woodcock_849' ...
#  'blushing_moose_275' 'powerful_worm_996' 'misty_mink_772']

# %%
print(cheflist[0])
# Out:
# super_carabeef_911

# %%
print(len(cheflist))
# Out:
# 7000

# %%
df['AuthorId'] = cheflist[:6871]

# %%
df.head()
# Out:
#    RecipeId                                         RecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2                           Spicy Tomato Rice Recipe
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  PrepTimeInMins  \
# 0  6 Karela Bitter Gourd Pavakkai - deseededSalt ...              15
# 1  2-1  2 cups rice - cooked 3 tomatoes 3 teaspoo...               5
# 2  1-12 cups Rice Vermicelli Noodles Thin1 Onion ...              20
# 3  500 grams Chicken2 Onion - chopped1 Tomato - c...              15
# 4  1 tablespoon chana dal 1 tablespoon white urad...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# ...
